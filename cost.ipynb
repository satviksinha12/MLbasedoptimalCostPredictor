# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import mean_squared_error,r2_score
# Load the dataset
data = pd.read_csv("data.csv")

# Check the column names
print(data.columns)

x=data.values[:,0].reshape(-1,1)
y=data.values[:,1]
regr=linear_model.LinearRegression()
regr.fit(x,y)
print('coefficient: \n',regr.coef_ )

print('Intercept: \n',regr.intercept_)
newdata=pd.read_csv("new-data.csv")

y_pred=regr.predict(newdata)
y_pred
plt.scatter(x,y,color='red')
plt.scatter(newdata,y_pred,color='blue')
plt.plot(newdata,y_pred,color='blue',linewidth=3)
plt.show
# Out:
# Index(['No. of items(x)', 'Total Cost(Y)'], dtype='object')
# coefficient:
#  [6.17826537]
# Intercept:
#  59.092325968645895
# C:\Users\satvi\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>
